# %%
class UpbitDataFetcher:
    def __init__(self, batch_size=30, delay=2):
        self.base_url = "https://api.upbit.com/v1/candles/minutes/1"
        self.headers = {"accept": "application/json"}
        self.shit_list = [
            'KRW-GRS', 'KRW-SBD', 'KRW-BOUNTY', 'KRW-MOC', 'KRW-TT', 'KRW-GAME2',
            'KRW-MED', 'KRW-MLK', 'KRW-DKA', 'KRW-BORA', 'KRW-AHT', 'KRW-MVL',
            'KRW-HUNT', 'KRW-CRO', 'KRW-FCT2', 'KRW-HPO', 'KRW-CBK', 'KRW-AQT',
            'KRW-STRIKE', 'KRW-META', 'KRW-CTC', 'KRW-MNT', 'KRW-TAIKO', 'KRW-SOL',
            'KRW-BLAST', 'KRW-ATH', 'KRW-CARV', 'KRW-BTC', 'KRW-ETC', 'KRW-ETH', 
        ]
        self.filtered_pairs = []
        self.all_candles_data = []
        self.batch_size = batch_size
        self.delay = delay

    def fetch_market_pairs(self):
        """Получает список всех пар с Upbit и фильтрует их."""
        url = "https://api.upbit.com/v1/market/all?isDetails=true"
        try:
            response = requests.get(url, headers=self.headers)
            response.raise_for_status()
            markets_data = response.json()

            df = pd.DataFrame(markets_data)
            df = df.rename(columns={
                'market': 'Market Pair',
                'korean_name': 'Korean Name',
                'english_name': 'English Name'
            })

            # Фильтруем пары
            self.filtered_pairs = df[
                df['Market Pair'].str.startswith('KRW-') & 
                ~df['Market Pair'].isin(self.shit_list)
            ]['Market Pair'].tolist()

            print(f"Filtered market pairs: {self.filtered_pairs[:5]} ...")
        except requests.exceptions.RequestException as e:
            print(f"An error occurred: {e}")

    async def fetch_candle_data(self, pair, session):
        """Асинхронный метод для получения свечей по одной паре."""
        to_date = (datetime.utcnow() - timedelta(minutes=1)).strftime('%Y-%m-%dT%H:%M:%S')
        params = {
            'market': pair,
            'count': 1,
            'to': to_date
        }
        try:
            async with session.get(self.base_url, params=params, headers=self.headers) as response:
                if response.status == 429:
                    print(f"Rate limit exceeded for {pair}. Retrying after 1 second.")
                    await asyncio.sleep(1)
                    return await self.fetch_candle_data(pair, session)  # Повторить запрос
                response.raise_for_status()
                candles = await response.json()

                if candles:
                    candles[0]['market'] = pair
                    self.all_candles_data.append(candles[0])
                    print(f"Successfully fetched data for {pair}")
                else:
                    print(f"No data returned for {pair}")
        except aiohttp.ClientError as e:
            print(f"Failed to fetch data for {pair}: {e}")

    async def fetch_candles_batch(self, pairs_batch, session):
        """Обрабатывает пакет пар."""
        tasks = [self.fetch_candle_data(pair, session) for pair in pairs_batch]
        await asyncio.gather(*tasks)

    async def fetch_all_candles(self):
        """Главный метод для получения данных по пакетам."""
        async with aiohttp.ClientSession() as session:
            for i in range(0, len(self.filtered_pairs), self.batch_size):
                batch = self.filtered_pairs[i:i + self.batch_size]
                print(f"Fetching batch {i // self.batch_size + 1} of {len(self.filtered_pairs) // self.batch_size + 1}")
                await self.fetch_candles_batch(batch, session)
                await asyncio.sleep(self.delay)  # Задержка между пакетами

    def save_to_csv(self):
        """Сохраняет собранные данные в CSV."""
        if self.all_candles_data:
            df = pd.DataFrame(self.all_candles_data)
            df['candle_date_time_utc'] = pd.to_datetime(df['candle_date_time_utc'])
            df.to_csv("upbit_minute_candles.csv", index=False)
            print("Сохранены свечи:", df.head())

    def run(self):
        """Запуск сбора данных."""
        print("Fetching Upbit market pairs...")
        self.fetch_market_pairs()
        print("Fetching candles...")
        asyncio.run(self.fetch_all_candles())
        self.save_to_csv()


# Пример использования:
fetcher = UpbitDataFetcher(batch_size=30, delay=2)
fetcher.run()
# Out:
# Fetching Upbit market pairs...
# Filtered market pairs: ['KRW-NEO', 'KRW-MTL', 'KRW-XRP', 'KRW-SNT', 'KRW-WAVES'] ...
# Fetching candles...
# Fetching batch 1 of 4
# Successfully fetched data for KRW-POLYX
# Successfully fetched data for KRW-XEM
# Successfully fetched data for KRW-LOOM
# Successfully fetched data for KRW-ARK
# Successfully fetched data for KRW-STORJ
# Successfully fetched data for KRW-IOST
# Successfully fetched data for KRW-ADA
# Successfully fetched data for KRW-EOS
# Successfully fetched data for KRW-STEEM
# Rate limit exceeded for KRW-NEO. Retrying after 1 second.
# Successfully fetched data for KRW-ZRX
# Rate limit exceeded for KRW-SC. Retrying after 1 second.
# Rate limit exceeded for KRW-IQ. Retrying after 1 second.
# Rate limit exceeded for KRW-MTL. Retrying after 1 second.
# Rate limit exceeded for KRW-WAVES. Retrying after 1 second.
# Rate limit exceeded for KRW-SNT. Retrying after 1 second.
# Rate limit exceeded for KRW-POWR. Retrying after 1 second.
# Rate limit exceeded for KRW-ZIL. Retrying after 1 second.
# Rate limit exceeded for KRW-LSK. Retrying after 1 second.
# Rate limit exceeded for KRW-XRP. Retrying after 1 second.
# Rate limit exceeded for KRW-TRX. Retrying after 1 second.
# Rate limit exceeded for KRW-QTUM. Retrying after 1 second.
# Rate limit exceeded for KRW-BAT. Retrying after 1 second.
# Rate limit exceeded for KRW-XLM. Retrying after 1 second.
# Rate limit exceeded for KRW-CVC. Retrying after 1 second.
# Rate limit exceeded for KRW-ICX. Retrying after 1 second.
# Rate limit exceeded for KRW-BCH. Retrying after 1 second.
# Rate limit exceeded for KRW-BTG. Retrying after 1 second.
# Rate limit exceeded for KRW-ARDR. Retrying after 1 second.
# Rate limit exceeded for KRW-ONT. Retrying after 1 second.
# Successfully fetched data for KRW-NEO
# Successfully fetched data for KRW-SC
# Successfully fetched data for KRW-ZIL
# Successfully fetched data for KRW-MTL
# Successfully fetched data for KRW-IQ
# Successfully fetched data for KRW-WAVES
# Successfully fetched data for KRW-SNT
# Rate limit exceeded for KRW-XRP. Retrying after 1 second.
# Successfully fetched data for KRW-LSK
# Successfully fetched data for KRW-POWR
# Rate limit exceeded for KRW-QTUM. Retrying after 1 second.
# Rate limit exceeded for KRW-XLM. Retrying after 1 second.
# Rate limit exceeded for KRW-CVC. Retrying after 1 second.
# Successfully fetched data for KRW-TRX
# Successfully fetched data for KRW-BAT
# Rate limit exceeded for KRW-BTG. Retrying after 1 second.
# Rate limit exceeded for KRW-ICX. Retrying after 1 second.
# Rate limit exceeded for KRW-BCH. Retrying after 1 second.
# Rate limit exceeded for KRW-ARDR. Retrying after 1 second.
# Rate limit exceeded for KRW-ONT. Retrying after 1 second.
# Successfully fetched data for KRW-QTUM
# Successfully fetched data for KRW-XRP
# Successfully fetched data for KRW-XLM
# Successfully fetched data for KRW-CVC
# Successfully fetched data for KRW-BTG
# Successfully fetched data for KRW-BCH
# Successfully fetched data for KRW-ICX
# Successfully fetched data for KRW-ONT
# Successfully fetched data for KRW-ARDR
# Fetching batch 2 of 4
# Successfully fetched data for KRW-HIFI
# Successfully fetched data for KRW-ONG
# Successfully fetched data for KRW-GAS
# Successfully fetched data for KRW-ELF
# Successfully fetched data for KRW-THETA
# Rate limit exceeded for KRW-QKC. Retrying after 1 second.
# Successfully fetched data for KRW-KNC
# Successfully fetched data for KRW-BSV
# Rate limit exceeded for KRW-MBL. Retrying after 1 second.
# Successfully fetched data for KRW-BTT
# Rate limit exceeded for KRW-ANKR. Retrying after 1 second.
# Rate limit exceeded for KRW-MANA. Retrying after 1 second.
# Successfully fetched data for KRW-TFUEL
# Rate limit exceeded for KRW-AERGO. Retrying after 1 second.
# Successfully fetched data for KRW-ATOM
# Rate limit exceeded for KRW-IOTA. Retrying after 1 second.
# Rate limit exceeded for KRW-WAXP. Retrying after 1 second.
# Rate limit exceeded for KRW-HBAR. Retrying after 1 second.
# Rate limit exceeded for KRW-STPT. Retrying after 1 second.
# Rate limit exceeded for KRW-CHZ. Retrying after 1 second.
# Rate limit exceeded for KRW-VET. Retrying after 1 second.
# Rate limit exceeded for KRW-ORBS. Retrying after 1 second.
# Rate limit exceeded for KRW-STMX. Retrying after 1 second.
# Rate limit exceeded for KRW-KAVA. Retrying after 1 second.
# Rate limit exceeded for KRW-LINK. Retrying after 1 second.
# Rate limit exceeded for KRW-HIVE. Retrying after 1 second.
# Rate limit exceeded for KRW-JST. Retrying after 1 second.
# Rate limit exceeded for KRW-TON. Retrying after 1 second.
# Rate limit exceeded for KRW-XTZ. Retrying after 1 second.
# Rate limit exceeded for KRW-SXP. Retrying after 1 second.
# Successfully fetched data for KRW-QKC
# Successfully fetched data for KRW-MBL
# Successfully fetched data for KRW-ANKR
# Rate limit exceeded for KRW-IOTA. Retrying after 1 second.
# Successfully fetched data for KRW-HBAR
# Successfully fetched data for KRW-AERGO
# Successfully fetched data for KRW-MANA
# Successfully fetched data for KRW-WAXP
# Rate limit exceeded for KRW-VET. Retrying after 1 second.
# Rate limit exceeded for KRW-ORBS. Retrying after 1 second.
# Successfully fetched data for KRW-CHZ
# Successfully fetched data for KRW-STMX
# Successfully fetched data for KRW-STPT
# Successfully fetched data for KRW-LINK
# Rate limit exceeded for KRW-KAVA. Retrying after 1 second.
# Rate limit exceeded for KRW-JST. Retrying after 1 second.
# Rate limit exceeded for KRW-TON. Retrying after 1 second.
# Rate limit exceeded for KRW-HIVE. Retrying after 1 second.
# Rate limit exceeded for KRW-SXP. Retrying after 1 second.
# Rate limit exceeded for KRW-XTZ. Retrying after 1 second.
# Successfully fetched data for KRW-IOTA
# Successfully fetched data for KRW-VET
# Successfully fetched data for KRW-ORBS
# Successfully fetched data for KRW-KAVA
# Successfully fetched data for KRW-JST
# Successfully fetched data for KRW-TON
# Successfully fetched data for KRW-HIVE
# Successfully fetched data for KRW-SXP
# Successfully fetched data for KRW-XTZ
# Fetching batch 3 of 4
# Successfully fetched data for KRW-GLM
# Successfully fetched data for KRW-STRAX
# Successfully fetched data for KRW-SAND
# Successfully fetched data for KRW-PUNDIX
# Rate limit exceeded for KRW-DOGE. Retrying after 1 second.
# Successfully fetched data for KRW-STX
# Successfully fetched data for KRW-FLOW
# Successfully fetched data for KRW-AXS
# Successfully fetched data for KRW-AAVE
# Successfully fetched data for KRW-NEAR
# Rate limit exceeded for KRW-POL. Retrying after 1 second.
# Successfully fetched data for KRW-1INCH
# Rate limit exceeded for KRW-XEC. Retrying after 1 second.
# Rate limit exceeded for KRW-AVAX. Retrying after 1 second.
# Successfully fetched data for KRW-ALGO
# Rate limit exceeded for KRW-T. Retrying after 1 second.
# Rate limit exceeded for KRW-CELO. Retrying after 1 second.
# Rate limit exceeded for KRW-DOT. Retrying after 1 second.
# Rate limit exceeded for KRW-APT. Retrying after 1 second.
# Rate limit exceeded for KRW-SHIB. Retrying after 1 second.
# Rate limit exceeded for KRW-MASK. Retrying after 1 second.
# Rate limit exceeded for KRW-GRT. Retrying after 1 second.
# Rate limit exceeded for KRW-SUI. Retrying after 1 second.
# Rate limit exceeded for KRW-ARB. Retrying after 1 second.
# Rate limit exceeded for KRW-BLUR. Retrying after 1 second.
# Rate limit exceeded for KRW-GMT. Retrying after 1 second.
# Rate limit exceeded for KRW-EGLD. Retrying after 1 second.
# Rate limit exceeded for KRW-IMX. Retrying after 1 second.
# Rate limit exceeded for KRW-MINA. Retrying after 1 second.
# Rate limit exceeded for KRW-SEI. Retrying after 1 second.
# Successfully fetched data for KRW-DOGE
# Successfully fetched data for KRW-POL
# Successfully fetched data for KRW-CELO
# Successfully fetched data for KRW-APT
# Successfully fetched data for KRW-AVAX
# Successfully fetched data for KRW-DOT
# Successfully fetched data for KRW-XEC
# Successfully fetched data for KRW-T
# Successfully fetched data for KRW-MASK
# Successfully fetched data for KRW-SHIB
# Rate limit exceeded for KRW-SUI. Retrying after 1 second.
# Rate limit exceeded for KRW-GRT. Retrying after 1 second.
# Rate limit exceeded for KRW-ARB. Retrying after 1 second.
# Rate limit exceeded for KRW-EGLD. Retrying after 1 second.
# Rate limit exceeded for KRW-BLUR. Retrying after 1 second.
# Rate limit exceeded for KRW-GMT. Retrying after 1 second.
# Rate limit exceeded for KRW-IMX. Retrying after 1 second.
# Rate limit exceeded for KRW-SEI. Retrying after 1 second.
# Rate limit exceeded for KRW-MINA. Retrying after 1 second.
# Successfully fetched data for KRW-SUI
# Successfully fetched data for KRW-EGLD
# Successfully fetched data for KRW-ARB
# Successfully fetched data for KRW-GRT
# Successfully fetched data for KRW-BLUR
# Successfully fetched data for KRW-MINA
# Successfully fetched data for KRW-SEI
# Successfully fetched data for KRW-GMT
# Successfully fetched data for KRW-IMX
# Fetching batch 4 of 4
# Successfully fetched data for KRW-PYTH
# Successfully fetched data for KRW-AKT
# Successfully fetched data for KRW-USDT
# Rate limit exceeded for KRW-ONDO. Retrying after 1 second.
# Successfully fetched data for KRW-ZETA
# Successfully fetched data for KRW-AUCTION
# Successfully fetched data for KRW-STG
# Successfully fetched data for KRW-ZRO
# Successfully fetched data for KRW-BEAM
# Successfully fetched data for KRW-ENS
# Rate limit exceeded for KRW-G. Retrying after 1 second.
# Successfully fetched data for KRW-JUP
# Successfully fetched data for KRW-PENDLE
# Successfully fetched data for KRW-ASTR
# Rate limit exceeded for KRW-BIGTIME. Retrying after 1 second.
# Rate limit exceeded for KRW-USDC. Retrying after 1 second.
# Rate limit exceeded for KRW-UXLINK. Retrying after 1 second.
# Rate limit exceeded for KRW-ID. Retrying after 1 second.
# Rate limit exceeded for KRW-W. Retrying after 1 second.
# Rate limit exceeded for KRW-CKB. Retrying after 1 second.
# Rate limit exceeded for KRW-MEW. Retrying after 1 second.
# Rate limit exceeded for KRW-UNI. Retrying after 1 second.
# Rate limit exceeded for KRW-AGLD. Retrying after 1 second.
# Rate limit exceeded for KRW-DRIFT. Retrying after 1 second.
# Rate limit exceeded for KRW-SAFE. Retrying after 1 second.
# Rate limit exceeded for KRW-PEPE. Retrying after 1 second.
# Rate limit exceeded for KRW-BONK. Retrying after 1 second.
# Rate limit exceeded for KRW-INJ. Retrying after 1 second.
# Successfully fetched data for KRW-USDC
# Successfully fetched data for KRW-BIGTIME
# Successfully fetched data for KRW-UXLINK
# Successfully fetched data for KRW-MEW
# Successfully fetched data for KRW-W
# Successfully fetched data for KRW-CKB
# Successfully fetched data for KRW-AGLD
# Successfully fetched data for KRW-DRIFT
# Successfully fetched data for KRW-ID
# Successfully fetched data for KRW-UNI
# Rate limit exceeded for KRW-SAFE. Retrying after 1 second.
# Rate limit exceeded for KRW-G. Retrying after 1 second.
# Successfully fetched data for KRW-ONDO
# Successfully fetched data for KRW-INJ
# Successfully fetched data for KRW-SAFE
# Successfully fetched data for KRW-G
# Successfully fetched data for KRW-PEPE
# Successfully fetched data for KRW-BONK
# Сохранены свечи:       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0  KRW-POLYX  2024-11-28 15:08:00  2024-11-29T00:08:00         508.00
# 1    KRW-XEM  2024-11-28 15:08:00  2024-11-29T00:08:00          38.52
# 2   KRW-LOOM  2024-11-28 15:08:00  2024-11-29T00:08:00         107.10
# 3    KRW-ARK  2024-11-28 15:08:00  2024-11-29T00:08:00        1000.00
# 4  KRW-STORJ  2024-11-28 15:08:00  2024-11-29T00:08:00         842.10
#
#    high_price  low_price  trade_price      timestamp  candle_acc_trade_price  \
# 0      508.00     508.00       508.00  1732806517635            5.031806e+06
# 1       38.52      38.49        38.49  1732806513698            1.857496e+06
# 2      107.10     107.10       107.10  1732806492646            2.500000e+04
# 3     1003.00    1000.00      1003.00  1732806527093            3.291898e+07
# 4      842.60     841.70       842.50  1732806535007            5.958813e+06
#
#    candle_acc_trade_volume  unit
# 0              9905.129242     1
# 1             48242.080530     1
# 2               233.426704     1
# 3             32903.884281     1
# 4              7077.904461     1

# %% [markdown]
# get candles for binance

# %%
import nest_asyncio

nest_asyncio.apply()  # Позволяет запускать asyncio.run() в существующем loop

class BinanceDataFetcher:
    def __init__(self):
        self.base_url_spot = "https://api.binance.com/api/v3/klines"
        self.base_url_perp = "https://fapi.binance.com/fapi/v1/klines"
        self.all_candles_data = []

    async def fetch_candle(self, session, base_url, pair, interval="1m"):
        """Получает одну минутную свечу для указанной пары с Binance."""
        params = {
            "symbol": pair.replace("/", ""),
            "interval": interval,
            "limit": 1,
            "endTime": int((datetime.utcnow() - timedelta(minutes=1)).timestamp() * 1000)
        }
        async with session.get(base_url, params=params) as response:
            if response.status == 200:
                data = await response.json()
                if data:
                    return {
                        "market": pair,
                        "candle_date_time_utc": datetime.utcfromtimestamp(data[0][0] / 1000).strftime("%Y-%m-%d %H:%M:%S"),
                        "opening_price": float(data[0][1]),
                        "high_price": float(data[0][2]),
                        "low_price": float(data[0][3]),
                        "trade_price": float(data[0][4]),
                        "candle_acc_trade_price": float(data[0][7]),
                        "candle_acc_trade_volume": float(data[0][5]),
                    }
            return None

    async def fetch_all_binance_candles(self, pairs):
        """Получает свечи для всех пар из списка, включая спот и perp."""
        async with aiohttp.ClientSession() as session:
            tasks = []
            for pair in pairs:
                tasks.append(self.fetch_candle(session, self.base_url_spot, pair))
                tasks.append(self.fetch_candle(session, self.base_url_perp, pair))

            results = await asyncio.gather(*tasks, return_exceptions=True)

            for i in range(0, len(results), 2):
                spot_data = results[i]
                perp_data = results[i + 1]
                pair = pairs[i // 2]

                if spot_data:
                    self.all_candles_data.append(spot_data)
                elif perp_data:
                    perp_data["market"] += " (perp)"
                    self.all_candles_data.append(perp_data)

    def save_to_csv(self):
        """Сохраняет полученные данные в CSV."""
        if self.all_candles_data:
            df = pd.DataFrame(self.all_candles_data)
            df.to_csv("binance_minute_candles.csv", index=False)
            print("Сохранены свечи:", df.head())

    def run(self, pairs):
        """Запускает сбор данных по свечам."""
        print("Fetching Binance candles...")
        asyncio.run(self.fetch_all_binance_candles(pairs))
        self.save_to_csv()


# Пример использования:
pairs_to_check = [
    "BTC/USDT", "ETH/USDT", "XRP/USDT", "BNB/USDT", "SOL/USDT", "DOGE/USDT",  # Добавьте сюда нужные пары
    "GRS/USDT", "SBD/USDT"  # Пары, которые могут быть не найдены
]

fetcher = BinanceDataFetcher()
fetcher.run(pairs_to_check)
# Out:
# Fetching Binance candles...
# Сохранены свечи:      market candle_date_time_utc  opening_price  high_price   low_price  \
# 0  BTC/USDT  2024-11-28 11:13:00     94952.2900  95000.0000  94947.7500
# 1  ETH/USDT  2024-11-28 11:13:00      3598.2500   3602.3000   3597.7200
# 2  XRP/USDT  2024-11-28 11:13:00         1.4497      1.4526      1.4493
# 3  BNB/USDT  2024-11-28 11:13:00       656.5100    657.4000    656.3400
# 4  SOL/USDT  2024-11-28 11:13:00       235.6000    235.8500    235.5600
#
#    trade_price  candle_acc_trade_price  candle_acc_trade_volume
# 0   94999.9900           772837.759326                  8.13646
# 1    3602.2900           502370.398107                139.53740
# 2       1.4526           307995.935800             212225.00000
# 3     657.1400           409393.670890                623.07800
# 4     235.8400           240847.936020               1021.73900

# %%
import nest_asyncio
import asyncio
import aiohttp
import requests
import pandas as pd
from datetime import datetime, timedelta

nest_asyncio.apply()  # Позволяет запускать asyncio.run() в существующем loop

# Класс для получения данных с Upbit
class UpbitDataFetcher:
    def __init__(self, batch_size=30, delay=2):
        self.base_url = "https://api.upbit.com/v1/candles/minutes/1"
        self.headers = {"accept": "application/json"}
        # Убираем пару KRW-USDT из shit_list
        self.shit_list = [
            'KRW-GRS', 'KRW-SBD', 'KRW-BOUNTY', 'KRW-MOC', 'KRW-TT', 'KRW-GAME2',
            'KRW-MED', 'KRW-MLK', 'KRW-DKA', 'KRW-BORA', 'KRW-AHT', 'KRW-MVL',
            'KRW-HUNT', 'KRW-CRO', 'KRW-FCT2', 'KRW-HPO', 'KRW-CBK', 'KRW-AQT',
            'KRW-STRIKE', 'KRW-META', 'KRW-CTC', 'KRW-MNT', 'KRW-TAIKO', 'KRW-SOL',
            'KRW-BLAST', 'KRW-ATH', 'KRW-CARV', 'KRW-BTC', 'KRW-ETC', 'KRW-ETH', 
        ]
        self.filtered_pairs = []
        self.all_candles_data = []
        self.batch_size = batch_size
        self.delay = delay
        self.krw_usdt_rate = None  # Это будет хранить курс KRW-USDT

    def fetch_market_pairs(self):
        """Получает список всех пар с Upbit и фильтрует их."""
        url = "https://api.upbit.com/v1/market/all?isDetails=true"
        try:
            response = requests.get(url, headers=self.headers)
            response.raise_for_status()
            markets_data = response.json()

            df = pd.DataFrame(markets_data)
            df = df.rename(columns={
                'market': 'Market Pair',
                'korean_name': 'Korean Name',
                'english_name': 'English Name'
            })

            # Фильтруем пары
            self.filtered_pairs = df[
                df['Market Pair'].str.startswith('KRW-') & 
                ~df['Market Pair'].isin(self.shit_list)
            ]['Market Pair'].tolist()

            print(f"Filtered market pairs: {self.filtered_pairs[:5]} ...")
        except requests.exceptions.RequestException as e:
            print(f"An error occurred: {e}")

    async def fetch_krw_usdt_rate(self, session):
        """Получает курс KRW-USDT для конвертации."""
        url = "https://api.upbit.com/v1/ticker"
        params = {"markets": "KRW-USDT"}
        try:
            async with session.get(url, params=params) as response:
                if response.status == 200:
                    data = await response.json()
                    if data:
                        self.krw_usdt_rate = data[0]["trade_price"]
                        print(f"KRW/USDT rate: {self.krw_usdt_rate}")
        except aiohttp.ClientError as e:
            print(f"Failed to fetch KRW-USDT rate: {e}")

    async def fetch_candle_data(self, pair, session):
        """Асинхронный метод для получения свечей по одной паре."""
        to_date = (datetime.utcnow() - timedelta(minutes=1)).strftime('%Y-%m-%dT%H:%M:%S')
        params = {
            'market': pair,
            'count': 1,
            'to': to_date
        }
        try:
            async with session.get(self.base_url, params=params, headers=self.headers) as response:
                if response.status == 429:
                    print(f"Rate limit exceeded for {pair}. Retrying after 1 second.")
                    await asyncio.sleep(1)
                    return await self.fetch_candle_data(pair, session)  # Повторить запрос
                response.raise_for_status()
                candles = await response.json()

                if candles:
                    # Конвертируем цены в доллары, если пара начинается с 'KRW-'
                    if pair.startswith("KRW-") and self.krw_usdt_rate:
                        for candle in candles:
                            candle['opening_price'] /= self.krw_usdt_rate
                            candle['high_price'] /= self.krw_usdt_rate
                            candle['low_price'] /= self.krw_usdt_rate
                            candle['trade_price'] /= self.krw_usdt_rate
                            candle['candle_acc_trade_price'] /= self.krw_usdt_rate
                            candle['candle_acc_trade_volume'] /= self.krw_usdt_rate

                    candles[0]['market'] = pair
                    self.all_candles_data.append(candles[0])
                    print(f"Successfully fetched data for {pair}")
                else:
                    print(f"No data returned for {pair}")
        except aiohttp.ClientError as e:
            print(f"Failed to fetch data for {pair}: {e}")

    async def fetch_candles_batch(self, pairs_batch, session):
        """Обрабатывает пакет пар."""
        tasks = [self.fetch_candle_data(pair, session) for pair in pairs_batch]
        await asyncio.gather(*tasks)

    async def fetch_all_candles(self):
        """Главный метод для получения данных по пакетам."""
        async with aiohttp.ClientSession() as session:
            await self.fetch_krw_usdt_rate(session)  # Получаем курс KRW-USDT
            for i in range(0, len(self.filtered_pairs), self.batch_size):
                batch = self.filtered_pairs[i:i + self.batch_size]
                print(f"Fetching batch {i // self.batch_size + 1} of {len(self.filtered_pairs) // self.batch_size + 1}")
                await self.fetch_candles_batch(batch, session)
                await asyncio.sleep(self.delay)  # Задержка между пакетами

    def save_to_csv(self):
        """Сохраняет собранные данные в CSV."""
        if self.all_candles_data:
            df = pd.DataFrame(self.all_candles_data)
            df['candle_date_time_utc'] = pd.to_datetime(df['candle_date_time_utc'])
            df.to_csv("upbit_minute_candles.csv", index=False)
            print("Сохранены свечи:", df.head())

    def run(self):
        """Запуск сбора данных."""
        print("Fetching Upbit market pairs...")
        self.fetch_market_pairs()
        print("Fetching candles...")
        asyncio.run(self.fetch_all_candles())
        self.save_to_csv()


# Класс для получения данных с Binance
class BinanceDataFetcher:
    def __init__(self):
        self.base_url_spot = "https://api.binance.com/api/v3/klines"
        self.base_url_perp = "https://fapi.binance.com/fapi/v1/klines"
        self.all_candles_data = []

    async def fetch_candle(self, session, base_url, pair, interval="1m"):
        """Получает одну минутную свечу для указанной пары с Binance."""
        params = {
            "symbol": pair.replace("/", ""),
            "interval": interval,
            "limit": 1,
            "endTime": int((datetime.utcnow() - timedelta(minutes=1)).timestamp() * 1000)
        }
        async with session.get(base_url, params=params) as response:
            if response.status == 200:
                data = await response.json()
                if data:
                    return {
                        "market": pair,
                        "candle_date_time_utc": datetime.utcfromtimestamp(data[0][0] / 1000).strftime("%Y-%m-%d %H:%M:%S"),
                        "opening_price": float(data[0][1]),
                        "high_price": float(data[0][2]),
                        "low_price": float(data[0][3]),
                        "trade_price": float(data[0][4]),
                        "candle_acc_trade_price": float(data[0][7]),
                        "candle_acc_trade_volume": float(data[0][5]),
                    }
            return None

    async def fetch_all_binance_candles(self, pairs):
        """Получает свечи для всех пар из списка, включая спот и perp."""
        async with aiohttp.ClientSession() as session:
            tasks = []
            for pair in pairs:
                tasks.append(self.fetch_candle(session, self.base_url_spot, pair))
                tasks.append(self.fetch_candle(session, self.base_url_perp, pair))

            results = await asyncio.gather(*tasks, return_exceptions=True)

            for i in range(0, len(results), 2):
                spot_data = results[i]
                perp_data = results[i + 1]
                pair = pairs[i // 2]

                if spot_data:
                    self.all_candles_data.append(spot_data)
                if perp_data:
                    self.all_candles_data.append(perp_data)

    def get_binance_candles_df(self):
        """Возвращает данные с Binance в виде DataFrame."""
        return pd.DataFrame(self.all_candles_data)


# Основной процесс
def main():
    upbit_fetcher = UpbitDataFetcher()
    binance_fetcher = BinanceDataFetcher()

    # Получаем данные с Upbit и Binance
    upbit_fetcher.run()

    # Получаем данные с Binance
    binance_fetcher.fetch_all_binance_candles(upbit_fetcher.filtered_pairs)

    # Создаём единую таблицу
    upbit_data_df = pd.read_csv("upbit_minute_candles.csv")
    binance_data_df = binance_fetcher.get_binance_candles_df()

    # Объединяем данные в одну таблицу по ключу 'market'
    combined_df = pd.concat([upbit_data_df, binance_data_df]).reset_index(drop=True)

    print("Объединённые данные:")
    print(combined_df.head())

if __name__ == "__main__":
    main()
# Out:
# Fetching Upbit market pairs...
# Filtered market pairs: ['KRW-NEO', 'KRW-MTL', 'KRW-XRP', 'KRW-SNT', 'KRW-WAVES'] ...
# Fetching candles...
# KRW/USDT rate: 1402.0
# Fetching batch 1 of 4
# Successfully fetched data for KRW-NEO
# Successfully fetched data for KRW-LSK
# Successfully fetched data for KRW-BCH
# Successfully fetched data for KRW-STORJ
# Successfully fetched data for KRW-IOST
# Successfully fetched data for KRW-ZIL
# Successfully fetched data for KRW-SNT
# Successfully fetched data for KRW-EOS
# Successfully fetched data for KRW-ZRX
# Rate limit exceeded for KRW-SC. Retrying after 1 second.
# Rate limit exceeded for KRW-XRP. Retrying after 1 second.
# Rate limit exceeded for KRW-MTL. Retrying after 1 second.
# Rate limit exceeded for KRW-ONT. Retrying after 1 second.
# Successfully fetched data for KRW-ADA
# Rate limit exceeded for KRW-ICX. Retrying after 1 second.
# Successfully fetched data for KRW-LOOM
# Rate limit exceeded for KRW-XLM. Retrying after 1 second.
# Rate limit exceeded for KRW-BTG. Retrying after 1 second.
# Rate limit exceeded for KRW-STEEM. Retrying after 1 second.
# Rate limit exceeded for KRW-CVC. Retrying after 1 second.
# Rate limit exceeded for KRW-WAVES. Retrying after 1 second.
# Rate limit exceeded for KRW-QTUM. Retrying after 1 second.
# Rate limit exceeded for KRW-ARDR. Retrying after 1 second.
# Rate limit exceeded for KRW-POWR. Retrying after 1 second.
# Rate limit exceeded for KRW-ARK. Retrying after 1 second.
# Rate limit exceeded for KRW-XEM. Retrying after 1 second.
# Rate limit exceeded for KRW-POLYX. Retrying after 1 second.
# Rate limit exceeded for KRW-TRX. Retrying after 1 second.
# Rate limit exceeded for KRW-IQ. Retrying after 1 second.
# Rate limit exceeded for KRW-BAT. Retrying after 1 second.
# Successfully fetched data for KRW-XRP
# Successfully fetched data for KRW-SC
# Successfully fetched data for KRW-XLM
# Successfully fetched data for KRW-MTL
# Successfully fetched data for KRW-ICX
# Successfully fetched data for KRW-ONT
# Rate limit exceeded for KRW-ARDR. Retrying after 1 second.
# Successfully fetched data for KRW-STEEM
# Successfully fetched data for KRW-BTG
# Rate limit exceeded for KRW-POWR. Retrying after 1 second.
# Rate limit exceeded for KRW-WAVES. Retrying after 1 second.
# Rate limit exceeded for KRW-ARK. Retrying after 1 second.
# Rate limit exceeded for KRW-XEM. Retrying after 1 second.
# Rate limit exceeded for KRW-TRX. Retrying after 1 second.
# Rate limit exceeded for KRW-QTUM. Retrying after 1 second.
# Successfully fetched data for KRW-CVC
# Successfully fetched data for KRW-POLYX
# Rate limit exceeded for KRW-IQ. Retrying after 1 second.
# Rate limit exceeded for KRW-BAT. Retrying after 1 second.
# Successfully fetched data for KRW-ARDR
# Successfully fetched data for KRW-ARK
# Successfully fetched data for KRW-TRX
# Successfully fetched data for KRW-QTUM
# Successfully fetched data for KRW-POWR
# Successfully fetched data for KRW-IQ
# Successfully fetched data for KRW-WAVES
# Successfully fetched data for KRW-XEM
# Successfully fetched data for KRW-BAT
# Fetching batch 2 of 4
# Successfully fetched data for KRW-ONG
# Successfully fetched data for KRW-BSV
# Successfully fetched data for KRW-KNC
# Successfully fetched data for KRW-THETA
# Rate limit exceeded for KRW-QKC. Retrying after 1 second.
# Rate limit exceeded for KRW-ANKR. Retrying after 1 second.
# Rate limit exceeded for KRW-AERGO. Retrying after 1 second.
# Successfully fetched data for KRW-BTT
# Successfully fetched data for KRW-GAS
# Successfully fetched data for KRW-ELF
# Rate limit exceeded for KRW-MBL. Retrying after 1 second.
# Rate limit exceeded for KRW-ATOM. Retrying after 1 second.
# Rate limit exceeded for KRW-ORBS. Retrying after 1 second.
# Rate limit exceeded for KRW-MANA. Retrying after 1 second.
# Successfully fetched data for KRW-HBAR
# Successfully fetched data for KRW-STPT
# Successfully fetched data for KRW-TFUEL
# Rate limit exceeded for KRW-IOTA. Retrying after 1 second.
# Rate limit exceeded for KRW-XTZ. Retrying after 1 second.
# Rate limit exceeded for KRW-WAXP. Retrying after 1 second.
# Rate limit exceeded for KRW-VET. Retrying after 1 second.
# Rate limit exceeded for KRW-TON. Retrying after 1 second.
# Rate limit exceeded for KRW-LINK. Retrying after 1 second.
# Rate limit exceeded for KRW-JST. Retrying after 1 second.
# Rate limit exceeded for KRW-HIFI. Retrying after 1 second.
# Rate limit exceeded for KRW-HIVE. Retrying after 1 second.
# Rate limit exceeded for KRW-STMX. Retrying after 1 second.
# Rate limit exceeded for KRW-CHZ. Retrying after 1 second.
# Rate limit exceeded for KRW-KAVA. Retrying after 1 second.
# Rate limit exceeded for KRW-SXP. Retrying after 1 second.
# Successfully fetched data for KRW-QKC
# Successfully fetched data for KRW-ANKR
# Successfully fetched data for KRW-AERGO
# Successfully fetched data for KRW-WAXP
# Rate limit exceeded for KRW-MANA. Retrying after 1 second.
# Successfully fetched data for KRW-MBL
# Successfully fetched data for KRW-ATOM
# Successfully fetched data for KRW-IOTA
# Successfully fetched data for KRW-ORBS
# Rate limit exceeded for KRW-HIFI. Retrying after 1 second.
# Rate limit exceeded for KRW-TON. Retrying after 1 second.
# Successfully fetched data for KRW-XTZ
# Rate limit exceeded for KRW-HIVE. Retrying after 1 second.
# Rate limit exceeded for KRW-VET. Retrying after 1 second.
# Rate limit exceeded for KRW-JST. Retrying after 1 second.
# Rate limit exceeded for KRW-SXP. Retrying after 1 second.
# Successfully fetched data for KRW-STMX
# Rate limit exceeded for KRW-LINK. Retrying after 1 second.
# Rate limit exceeded for KRW-CHZ. Retrying after 1 second.
# Rate limit exceeded for KRW-KAVA. Retrying after 1 second.
# Successfully fetched data for KRW-MANA
# Successfully fetched data for KRW-HIVE
# Successfully fetched data for KRW-HIFI
# Successfully fetched data for KRW-JST
# Successfully fetched data for KRW-LINK
# Successfully fetched data for KRW-TON
# Successfully fetched data for KRW-SXP
# Successfully fetched data for KRW-VET
# Successfully fetched data for KRW-CHZ
# Successfully fetched data for KRW-KAVA
# Fetching batch 3 of 4
# Successfully fetched data for KRW-DOT
# Successfully fetched data for KRW-GLM
# Rate limit exceeded for KRW-STX. Retrying after 1 second.
# Successfully fetched data for KRW-SAND
# Successfully fetched data for KRW-STRAX
# Successfully fetched data for KRW-AXS
# Rate limit exceeded for KRW-FLOW. Retrying after 1 second.
# Successfully fetched data for KRW-XEC
# Successfully fetched data for KRW-PUNDIX
# Rate limit exceeded for KRW-NEAR. Retrying after 1 second.
# Successfully fetched data for KRW-DOGE
# Rate limit exceeded for KRW-POL. Retrying after 1 second.
# Successfully fetched data for KRW-1INCH
# Rate limit exceeded for KRW-ALGO. Retrying after 1 second.
# Rate limit exceeded for KRW-AVAX. Retrying after 1 second.
# Successfully fetched data for KRW-T
# Rate limit exceeded for KRW-APT. Retrying after 1 second.
# Successfully fetched data for KRW-AAVE
# Rate limit exceeded for KRW-CELO. Retrying after 1 second.
# Rate limit exceeded for KRW-SHIB. Retrying after 1 second.
# Rate limit exceeded for KRW-GMT. Retrying after 1 second.
# Rate limit exceeded for KRW-SEI. Retrying after 1 second.
# Rate limit exceeded for KRW-SUI. Retrying after 1 second.
# Rate limit exceeded for KRW-BLUR. Retrying after 1 second.
# Rate limit exceeded for KRW-MASK. Retrying after 1 second.
# Rate limit exceeded for KRW-ARB. Retrying after 1 second.
# Rate limit exceeded for KRW-EGLD. Retrying after 1 second.
# Rate limit exceeded for KRW-IMX. Retrying after 1 second.
# Successfully fetched data for KRW-POL
# Successfully fetched data for KRW-STX
# Successfully fetched data for KRW-ALGO
# Successfully fetched data for KRW-FLOW
# Successfully fetched data for KRW-AVAX
# Successfully fetched data for KRW-CELO
# Rate limit exceeded for KRW-ARB. Retrying after 1 second.
# Successfully fetched data for KRW-NEAR
# Rate limit exceeded for KRW-APT. Retrying after 1 second.
# Rate limit exceeded for KRW-SEI. Retrying after 1 second.
# Rate limit exceeded for KRW-SUI. Retrying after 1 second.
# Successfully fetched data for KRW-SHIB
# Successfully fetched data for KRW-BLUR
# Successfully fetched data for KRW-EGLD
# Rate limit exceeded for KRW-MASK. Retrying after 1 second.
# Successfully fetched data for KRW-GMT
# Rate limit exceeded for KRW-GRT. Retrying after 1 second.
# Rate limit exceeded for KRW-MINA. Retrying after 1 second.
# Successfully fetched data for KRW-IMX
# Successfully fetched data for KRW-ARB
# Successfully fetched data for KRW-SEI
# Successfully fetched data for KRW-APT
# Successfully fetched data for KRW-SUI
# Successfully fetched data for KRW-MASK
# Successfully fetched data for KRW-GRT
# Successfully fetched data for KRW-MINA
# Fetching batch 4 of 4
# Successfully fetched data for KRW-ZETA
# Successfully fetched data for KRW-STG
# Successfully fetched data for KRW-AUCTION
# Successfully fetched data for KRW-BEAM
# Successfully fetched data for KRW-USDT
# Rate limit exceeded for KRW-ZRO. Retrying after 1 second.
# Successfully fetched data for KRW-ONDO
# Rate limit exceeded for KRW-JUP. Retrying after 1 second.
# Rate limit exceeded for KRW-USDC. Retrying after 1 second.
# Rate limit exceeded for KRW-G. Retrying after 1 second.
# Rate limit exceeded for KRW-ENS. Retrying after 1 second.
# Rate limit exceeded for KRW-SAFE. Retrying after 1 second.
# Rate limit exceeded for KRW-ID. Retrying after 1 second.
# Successfully fetched data for KRW-ASTR
# Rate limit exceeded for KRW-W. Retrying after 1 second.
# Successfully fetched data for KRW-UXLINK
# Rate limit exceeded for KRW-CKB. Retrying after 1 second.
# Successfully fetched data for KRW-BIGTIME
# Successfully fetched data for KRW-PYTH
# Rate limit exceeded for KRW-INJ. Retrying after 1 second.
# Rate limit exceeded for KRW-AKT. Retrying after 1 second.
# Rate limit exceeded for KRW-DRIFT. Retrying after 1 second.
# Rate limit exceeded for KRW-UNI. Retrying after 1 second.
# Rate limit exceeded for KRW-AGLD. Retrying after 1 second.
# Rate limit exceeded for KRW-BONK. Retrying after 1 second.
# Rate limit exceeded for KRW-MEW. Retrying after 1 second.
# Rate limit exceeded for KRW-PEPE. Retrying after 1 second.
# Rate limit exceeded for KRW-PENDLE. Retrying after 1 second.
# Successfully fetched data for KRW-ENS
# Successfully fetched data for KRW-SAFE
# Successfully fetched data for KRW-ID
# Successfully fetched data for KRW-USDC
# Successfully fetched data for KRW-G
# Rate limit exceeded for KRW-INJ. Retrying after 1 second.
# Rate limit exceeded for KRW-UNI. Retrying after 1 second.
# Successfully fetched data for KRW-CKB
# Successfully fetched data for KRW-ZRO
# Successfully fetched data for KRW-JUP
# Rate limit exceeded for KRW-AKT. Retrying after 1 second.
# Successfully fetched data for KRW-W
# Rate limit exceeded for KRW-DRIFT. Retrying after 1 second.
# Successfully fetched data for KRW-AGLD
# Successfully fetched data for KRW-PENDLE
# Rate limit exceeded for KRW-MEW. Retrying after 1 second.
# Rate limit exceeded for KRW-PEPE. Retrying after 1 second.
# Rate limit exceeded for KRW-BONK. Retrying after 1 second.
# Successfully fetched data for KRW-UNI
# Successfully fetched data for KRW-INJ
# Successfully fetched data for KRW-AKT
# Successfully fetched data for KRW-PEPE
# Successfully fetched data for KRW-BONK
# Successfully fetched data for KRW-DRIFT
# Successfully fetched data for KRW-MEW
# Сохранены свечи:       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-NEO  2024-11-28 15:25:00  2024-11-29T00:25:00      14.507846
# 1    KRW-LSK  2024-11-28 15:25:00  2024-11-29T00:25:00       1.216120
# 2    KRW-BCH  2024-11-28 15:25:00  2024-11-29T00:25:00     506.847361
# 3  KRW-STORJ  2024-11-28 15:25:00  2024-11-29T00:25:00       0.597646
# 4   KRW-IOST  2024-11-28 15:25:00  2024-11-29T00:25:00       0.007810
#
#    high_price   low_price  trade_price      timestamp  candle_acc_trade_price  \
# 0   14.550642   14.507846    14.507846  1732807539549             6107.240060
# 1    1.216120    1.216120     1.216120  1732807555912             2139.800285
# 2  508.844508  506.348074   508.844508  1732807543139            51512.577387
# 3    0.598288    0.596933     0.598288  1732807545769             6457.897598
# 4    0.007817    0.007810     0.007817  1732807540206              679.024114
#
#    candle_acc_trade_volume  unit
# 0                 0.300251     1
# 1                 1.255015     1
# 2                 0.072409     1
# 3                 7.705900     1
# 4                61.964151     1
# Объединённые данные:
#       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0    KRW-NEO  2024-11-28 15:25:00  2024-11-29T00:25:00      14.507846
# 1    KRW-LSK  2024-11-28 15:25:00  2024-11-29T00:25:00       1.216120
# 2    KRW-BCH  2024-11-28 15:25:00  2024-11-29T00:25:00     506.847361
# 3  KRW-STORJ  2024-11-28 15:25:00  2024-11-29T00:25:00       0.597646
# 4   KRW-IOST  2024-11-28 15:25:00  2024-11-29T00:25:00       0.007810
#
#    high_price   low_price  trade_price      timestamp  candle_acc_trade_price  \
# 0   14.550642   14.507846    14.507846  1732807539549             6107.240060
# 1    1.216120    1.216120     1.216120  1732807555912             2139.800285
# 2  508.844508  506.348074   508.844508  1732807543139            51512.577387
# 3    0.598288    0.596933     0.598288  1732807545769             6457.897598
# 4    0.007817    0.007810     0.007817  1732807540206              679.024114
#
#    candle_acc_trade_volume  unit
# 0                 0.300251     1
# 1                 1.255015     1
# 2                 0.072409     1
# 3                 7.705900     1
# 4                61.964151     1
# /var/folders/t5/lm8r5ssn6mv9kms3b4kjsyrh0000gn/T/ipykernel_84314/4270169070.py:201: RuntimeWarning: coroutine 'BinanceDataFetcher.fetch_all_binance_candles' was never awaited
#   binance_fetcher.fetch_all_binance_candles(upbit_fetcher.filtered_pairs)
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback

# %%
import nest_asyncio
import asyncio
import aiohttp
import requests
import pandas as pd
from datetime import datetime, timedelta

nest_asyncio.apply()  # Позволяет запускать asyncio.run() в существующем loop

# Класс для получения данных с Upbit
class UpbitDataFetcher:
    def __init__(self, batch_size=30, delay=2):
        self.base_url = "https://api.upbit.com/v1/candles/minutes/1"
        self.headers = {"accept": "application/json"}
        # Убираем пару KRW-USDT из shit_list
        self.shit_list = [
            'KRW-GRS', 'KRW-SBD', 'KRW-BOUNTY', 'KRW-MOC', 'KRW-TT', 'KRW-GAME2',
            'KRW-MED', 'KRW-MLK', 'KRW-DKA', 'KRW-BORA', 'KRW-AHT', 'KRW-MVL',
            'KRW-HUNT', 'KRW-CRO', 'KRW-FCT2', 'KRW-HPO', 'KRW-CBK', 'KRW-AQT',
            'KRW-STRIKE', 'KRW-META', 'KRW-CTC', 'KRW-MNT', 'KRW-TAIKO', 'KRW-SOL',
            'KRW-BLAST', 'KRW-ATH', 'KRW-CARV', 'KRW-BTC', 'KRW-ETC', 'KRW-ETH', 
        ]
        self.filtered_pairs = []
        self.all_candles_data = []
        self.batch_size = batch_size
        self.delay = delay
        self.krw_usdt_rate = None  # Это будет хранить курс KRW-USDT

    def fetch_market_pairs(self):
        """Получает список всех пар с Upbit и фильтрует их."""
        url = "https://api.upbit.com/v1/market/all?isDetails=true"
        try:
            response = requests.get(url, headers=self.headers)
            response.raise_for_status()
            markets_data = response.json()

            df = pd.DataFrame(markets_data)
            df = df.rename(columns={
                'market': 'Market Pair',
                'korean_name': 'Korean Name',
                'english_name': 'English Name'
            })

            # Фильтруем пары
            self.filtered_pairs = df[
                df['Market Pair'].str.startswith('KRW-') & 
                ~df['Market Pair'].isin(self.shit_list)
            ]['Market Pair'].tolist()

            print(f"Filtered market pairs: {self.filtered_pairs[:5]} ...")
        except requests.exceptions.RequestException as e:
            print(f"An error occurred: {e}")

    async def fetch_krw_usdt_rate(self, session):
        """Получает курс KRW-USDT для конвертации."""
        url = "https://api.upbit.com/v1/ticker"
        params = {"markets": "KRW-USDT"}
        try:
            async with session.get(url, params=params) as response:
                if response.status == 200:
                    data = await response.json()
                    if data:
                        self.krw_usdt_rate = data[0]["trade_price"]
                        print(f"KRW/USDT rate: {self.krw_usdt_rate}")
        except aiohttp.ClientError as e:
            print(f"Failed to fetch KRW-USDT rate: {e}")

    async def fetch_candle_data(self, pair, session):
        """Асинхронный метод для получения свечей по одной паре."""
        to_date = (datetime.utcnow() - timedelta(minutes=1)).strftime('%Y-%m-%dT%H:%M:%S')
        params = {
            'market': pair,
            'count': 1,
            'to': to_date
        }
        try:
            async with session.get(self.base_url, params=params, headers=self.headers) as response:
                if response.status == 429:
                    print(f"Rate limit exceeded for {pair}. Retrying after 1 second.")
                    await asyncio.sleep(1)
                    return await self.fetch_candle_data(pair, session)  # Повторить запрос
                response.raise_for_status()
                candles = await response.json()

                if candles:
                    # Конвертируем цены в доллары, если пара начинается с 'KRW-'
                    if pair.startswith("KRW-") and self.krw_usdt_rate:
                        for candle in candles:
                            candle['opening_price'] /= self.krw_usdt_rate
                            candle['high_price'] /= self.krw_usdt_rate
                            candle['low_price'] /= self.krw_usdt_rate
                            candle['trade_price'] /= self.krw_usdt_rate
                            candle['candle_acc_trade_price'] /= self.krw_usdt_rate
                            candle['candle_acc_trade_volume'] /= self.krw_usdt_rate

                    # Преобразуем KRW- в TOKEN-USDT
                    token = pair.replace("KRW-", "")
                    pair_in_usdt = f"{token}-USDT"
                    candle_data = candles[0]
                    candle_data['market'] = pair_in_usdt  # Меняем на стиль Binance
                    self.all_candles_data.append(candle_data)
                    print(f"Successfully fetched data for {pair}")
                else:
                    print(f"No data returned for {pair}")
        except aiohttp.ClientError as e:
            print(f"Failed to fetch data for {pair}: {e}")

    async def fetch_candles_batch(self, pairs_batch, session):
        """Обрабатывает пакет пар."""
        tasks = [self.fetch_candle_data(pair, session) for pair in pairs_batch]
        await asyncio.gather(*tasks)

    async def fetch_all_candles(self):
        """Главный метод для получения данных по пакетам."""
        async with aiohttp.ClientSession() as session:
            await self.fetch_krw_usdt_rate(session)  # Получаем курс KRW-USDT
            for i in range(0, len(self.filtered_pairs), self.batch_size):
                batch = self.filtered_pairs[i:i + self.batch_size]
                print(f"Fetching batch {i // self.batch_size + 1} of {len(self.filtered_pairs) // self.batch_size + 1}")
                await self.fetch_candles_batch(batch, session)
                await asyncio.sleep(self.delay)  # Задержка между пакетами

    def save_to_csv(self):
        """Сохраняет собранные данные в CSV."""
        if self.all_candles_data:
            df = pd.DataFrame(self.all_candles_data)
            df['candle_date_time_utc'] = pd.to_datetime(df['candle_date_time_utc'])
            df.to_csv("upbit_minute_candles_converted.csv", index=False)
            print("Сохранены свечи:", df.head())

    def run(self):
        """Запуск сбора данных."""
        print("Fetching Upbit market pairs...")
        self.fetch_market_pairs()
        print("Fetching candles...")
        asyncio.run(self.fetch_all_candles())
        self.save_to_csv()


# Класс для получения данных с Binance
class BinanceDataFetcher:
    def __init__(self):
        self.base_url_spot = "https://api.binance.com/api/v3/klines"
        self.base_url_perp = "https://fapi.binance.com/fapi/v1/klines"
        self.all_candles_data = []

    async def fetch_candle(self, session, base_url, pair, interval="1m"):
        """Получает одну минутную свечу для указанной пары с Binance."""
        params = {
            "symbol": pair.replace("/", ""),
            "interval": interval,
            "limit": 1,
            "endTime": int((datetime.utcnow() - timedelta(minutes=1)).timestamp() * 1000)
        }
        async with session.get(base_url, params=params) as response:
            if response.status == 200:
                data = await response.json()
                if data:
                    return {
                        "market": pair,
                        "candle_date_time_utc": datetime.utcfromtimestamp(data[0][0] / 1000).strftime("%Y-%m-%d %H:%M:%S"),
                        "opening_price": float(data[0][1]),
                        "high_price": float(data[0][2]),
                        "low_price": float(data[0][3]),
                        "trade_price": float(data[0][4]),
                        "candle_acc_trade_price": float(data[0][7]),
                        "candle_acc_trade_volume": float(data[0][5])
                    }
            return None

    async def fetch_candles_batch(self, pairs_batch, session):
        """Получает свечи по batch."""
        tasks = [
            self.fetch_candle(session, self.base_url_spot, pair) for pair in pairs_batch
        ]
        return await asyncio.gather(*tasks)

    def get_binance_candles_df(self, table):
        """Возвращает DF c Binance."""
        return pd.DataFrame(table)

    async def fetch_binance_data(self, pairs):
        results = []
        async with aiohttp.ClientSession() as session:
            tasks = [self.fetch_candle(session, self.base_url_spot, pair) for pair in pairs]
            results = await asyncio.gather(*tasks)
        return [x for x in results if x]

    def run(self, upbit_symbols):
        loop = asyncio.get_event_loop()
        results = loop.run_until_complete(self.fetch_binance_data(upbit_symbols))
        self.all_candles_data = results
        print(f'Fetched {len(results)} pairs')

    def save_to_csv(self):
        """Сохраняет собранные данные в CSV."""
        if self.all_candles_data:
            df = pd.DataFrame(self.all_candles_data)
            df['candle_date_time_utc'] = pd.to_datetime(df['candle_date_time_utc'])
            df.to_csv("binance_candles.csv", index=False)
            print("Сохранены свечи Binance:", df.head())

    def run(self, upbit_symbols):
        loop = asyncio.get_event_loop()
        results = loop.run_until_complete(self.fetch_binance_data(upbit_symbols))
        self.all_candles_data = results
        print(f'Fetched {len(results)} pairs')

def main():
    upbit_fetcher = UpbitDataFetcher()
    binance_fetcher = BinanceDataFetcher()
    upbit_fetcher.run()
    converted_upbit = pd.read_csv("upbit_minute_candles_converted.csv")
    unique_binance_markets = converted_upbit['market'].unique().tolist()
    binance_fetcher.run(unique_binance_markets)
    binance_df = binance_fetcher.get_binance_candles_df(binance_fetcher.all_candles_data)
    result = pd.concat([converted_upbit, binance_df])
    result.to_csv("all_candles_merged.csv")
    print("Готово. См. файл: all_candles_merged.csv")

if __name__ == "__main__":
    main()
# Out:
# Fetching Upbit market pairs...
# Filtered market pairs: ['KRW-NEO', 'KRW-MTL', 'KRW-XRP', 'KRW-SNT', 'KRW-WAVES'] ...
# Fetching candles...
# KRW/USDT rate: 1390.0
# Fetching batch 1 of 4
# Successfully fetched data for KRW-NEO
# Successfully fetched data for KRW-ONT
# Successfully fetched data for KRW-ARDR
# Successfully fetched data for KRW-XLM
# Successfully fetched data for KRW-SNT
# Successfully fetched data for KRW-IOST
# Successfully fetched data for KRW-STORJ
# Successfully fetched data for KRW-IQ
# Successfully fetched data for KRW-CVC
# Successfully fetched data for KRW-ARK
# Rate limit exceeded for KRW-QTUM. Retrying after 1 second.
# Rate limit exceeded for KRW-BAT. Retrying after 1 second.
# Rate limit exceeded for KRW-ZRX. Retrying after 1 second.
# Rate limit exceeded for KRW-LSK. Retrying after 1 second.
# Rate limit exceeded for KRW-EOS. Retrying after 1 second.
# Successfully fetched data for KRW-SC
# Rate limit exceeded for KRW-BTG. Retrying after 1 second.
# Rate limit exceeded for KRW-ADA. Retrying after 1 second.
# Rate limit exceeded for KRW-XRP. Retrying after 1 second.
# Rate limit exceeded for KRW-POWR. Retrying after 1 second.
# Rate limit exceeded for KRW-MTL. Retrying after 1 second.
# Rate limit exceeded for KRW-ZIL. Retrying after 1 second.
# Rate limit exceeded for KRW-BCH. Retrying after 1 second.
# Rate limit exceeded for KRW-TRX. Retrying after 1 second.
# Rate limit exceeded for KRW-STEEM. Retrying after 1 second.
# Rate limit exceeded for KRW-LOOM. Retrying after 1 second.
# Rate limit exceeded for KRW-ICX. Retrying after 1 second.
# Rate limit exceeded for KRW-WAVES. Retrying after 1 second.
# Rate limit exceeded for KRW-POLYX. Retrying after 1 second.
# Rate limit exceeded for KRW-XEM. Retrying after 1 second.
# Successfully fetched data for KRW-BAT
# Successfully fetched data for KRW-ZRX
# Successfully fetched data for KRW-LSK
# Successfully fetched data for KRW-EOS
# Successfully fetched data for KRW-QTUM
# Successfully fetched data for KRW-BTG
# Successfully fetched data for KRW-ADA
# Successfully fetched data for KRW-XRP
# Successfully fetched data for KRW-POWR
# Successfully fetched data for KRW-MTL
# Rate limit exceeded for KRW-ZIL. Retrying after 1 second.
# Rate limit exceeded for KRW-BCH. Retrying after 1 second.
# Rate limit exceeded for KRW-TRX. Retrying after 1 second.
# Rate limit exceeded for KRW-STEEM. Retrying after 1 second.
# Rate limit exceeded for KRW-ICX. Retrying after 1 second.
# Rate limit exceeded for KRW-LOOM. Retrying after 1 second.
# Rate limit exceeded for KRW-WAVES. Retrying after 1 second.
# Rate limit exceeded for KRW-POLYX. Retrying after 1 second.
# Rate limit exceeded for KRW-XEM. Retrying after 1 second.
# Successfully fetched data for KRW-BCH
# Successfully fetched data for KRW-TRX
# Successfully fetched data for KRW-ZIL
# Successfully fetched data for KRW-STEEM
# Successfully fetched data for KRW-ICX
# Successfully fetched data for KRW-WAVES
# Successfully fetched data for KRW-LOOM
# Successfully fetched data for KRW-POLYX
# Successfully fetched data for KRW-XEM
# Fetching batch 2 of 4
# Successfully fetched data for KRW-ONG
# Successfully fetched data for KRW-GAS
# Successfully fetched data for KRW-ELF
# Successfully fetched data for KRW-KNC
# Successfully fetched data for KRW-THETA
# Rate limit exceeded for KRW-AERGO. Retrying after 1 second.
# Successfully fetched data for KRW-BTT
# Rate limit exceeded for KRW-ANKR. Retrying after 1 second.
# Successfully fetched data for KRW-QKC
# Rate limit exceeded for KRW-ATOM. Retrying after 1 second.
# Rate limit exceeded for KRW-MBL. Retrying after 1 second.
# Successfully fetched data for KRW-TFUEL
# Rate limit exceeded for KRW-HBAR. Retrying after 1 second.
# Rate limit exceeded for KRW-IOTA. Retrying after 1 second.
# Successfully fetched data for KRW-BSV
# Rate limit exceeded for KRW-STPT. Retrying after 1 second.
# Rate limit exceeded for KRW-VET. Retrying after 1 second.
# Rate limit exceeded for KRW-ORBS. Retrying after 1 second.
# Successfully fetched data for KRW-WAXP
# Rate limit exceeded for KRW-HIFI. Retrying after 1 second.
# Rate limit exceeded for KRW-HIVE. Retrying after 1 second.
# Rate limit exceeded for KRW-CHZ. Retrying after 1 second.
# Rate limit exceeded for KRW-STMX. Retrying after 1 second.
# Rate limit exceeded for KRW-KAVA. Retrying after 1 second.
# Rate limit exceeded for KRW-LINK. Retrying after 1 second.
# Rate limit exceeded for KRW-TON. Retrying after 1 second.
# Rate limit exceeded for KRW-SXP. Retrying after 1 second.
# Rate limit exceeded for KRW-XTZ. Retrying after 1 second.
# Rate limit exceeded for KRW-JST. Retrying after 1 second.
# Rate limit exceeded for KRW-MANA. Retrying after 1 second.
# Successfully fetched data for KRW-AERGO
# Successfully fetched data for KRW-ANKR
# Successfully fetched data for KRW-ATOM
# Successfully fetched data for KRW-HBAR
# Successfully fetched data for KRW-MBL
# Rate limit exceeded for KRW-VET. Retrying after 1 second.
# Successfully fetched data for KRW-STPT
# Rate limit exceeded for KRW-HIFI. Retrying after 1 second.
# Successfully fetched data for KRW-IOTA
# Rate limit exceeded for KRW-HIVE. Retrying after 1 second.
# Successfully fetched data for KRW-ORBS
# Rate limit exceeded for KRW-STMX. Retrying after 1 second.
# Rate limit exceeded for KRW-LINK. Retrying after 1 second.
# Rate limit exceeded for KRW-TON. Retrying after 1 second.
# Successfully fetched data for KRW-CHZ
# Successfully fetched data for KRW-SXP
# Rate limit exceeded for KRW-XTZ. Retrying after 1 second.
# Rate limit exceeded for KRW-JST. Retrying after 1 second.
# Rate limit exceeded for KRW-KAVA. Retrying after 1 second.
# Rate limit exceeded for KRW-MANA. Retrying after 1 second.
# Successfully fetched data for KRW-VET
# Successfully fetched data for KRW-HIFI
# Successfully fetched data for KRW-LINK
# Successfully fetched data for KRW-MANA
# Successfully fetched data for KRW-STMX
# Successfully fetched data for KRW-HIVE
# Successfully fetched data for KRW-JST
# Successfully fetched data for KRW-KAVA
# Successfully fetched data for KRW-TON
# Successfully fetched data for KRW-XTZ
# Fetching batch 3 of 4
# Successfully fetched data for KRW-STRAX
# Successfully fetched data for KRW-DOT
# Successfully fetched data for KRW-GLM
# Successfully fetched data for KRW-DOGE
# Successfully fetched data for KRW-SAND
# Rate limit exceeded for KRW-POL. Retrying after 1 second.
# Successfully fetched data for KRW-PUNDIX
# Successfully fetched data for KRW-FLOW
# Rate limit exceeded for KRW-STX. Retrying after 1 second.
# Rate limit exceeded for KRW-AAVE. Retrying after 1 second.
# Rate limit exceeded for KRW-XEC. Retrying after 1 second.
# Successfully fetched data for KRW-NEAR
# Rate limit exceeded for KRW-EGLD. Retrying after 1 second.
# Rate limit exceeded for KRW-1INCH. Retrying after 1 second.
# Rate limit exceeded for KRW-ALGO. Retrying after 1 second.
# Rate limit exceeded for KRW-T. Retrying after 1 second.
# Successfully fetched data for KRW-AVAX
# Successfully fetched data for KRW-AXS
# Rate limit exceeded for KRW-SHIB. Retrying after 1 second.
# Rate limit exceeded for KRW-CELO. Retrying after 1 second.
# Rate limit exceeded for KRW-SUI. Retrying after 1 second.
# Rate limit exceeded for KRW-GRT. Retrying after 1 second.
# Rate limit exceeded for KRW-MASK. Retrying after 1 second.
# Rate limit exceeded for KRW-GMT. Retrying after 1 second.
# Rate limit exceeded for KRW-ARB. Retrying after 1 second.
# Rate limit exceeded for KRW-SEI. Retrying after 1 second.
# Rate limit exceeded for KRW-APT. Retrying after 1 second.
# Rate limit exceeded for KRW-BLUR. Retrying after 1 second.
# Rate limit exceeded for KRW-IMX. Retrying after 1 second.
# Rate limit exceeded for KRW-MINA. Retrying after 1 second.
# Successfully fetched data for KRW-POL
# Successfully fetched data for KRW-STX
# Successfully fetched data for KRW-AAVE
# Successfully fetched data for KRW-XEC
# Successfully fetched data for KRW-EGLD
# Successfully fetched data for KRW-1INCH
# Rate limit exceeded for KRW-MASK. Retrying after 1 second.
# Rate limit exceeded for KRW-SHIB. Retrying after 1 second.
# Rate limit exceeded for KRW-CELO. Retrying after 1 second.
# Successfully fetched data for KRW-GRT
# Successfully fetched data for KRW-ALGO
# Successfully fetched data for KRW-T
# Rate limit exceeded for KRW-ARB. Retrying after 1 second.
# Rate limit exceeded for KRW-SUI. Retrying after 1 second.
# Rate limit exceeded for KRW-APT. Retrying after 1 second.
# Rate limit exceeded for KRW-SEI. Retrying after 1 second.
# Rate limit exceeded for KRW-BLUR. Retrying after 1 second.
# Successfully fetched data for KRW-GMT
# Rate limit exceeded for KRW-IMX. Retrying after 1 second.
# Rate limit exceeded for KRW-MINA. Retrying after 1 second.
# Successfully fetched data for KRW-SHIB
# Successfully fetched data for KRW-MASK
# Successfully fetched data for KRW-CELO
# Successfully fetched data for KRW-SUI
# Successfully fetched data for KRW-ARB
# Successfully fetched data for KRW-BLUR
# Successfully fetched data for KRW-APT
# Successfully fetched data for KRW-SEI
# Successfully fetched data for KRW-IMX
# Successfully fetched data for KRW-MINA
# Fetching batch 4 of 4
# Successfully fetched data for KRW-ID
# Successfully fetched data for KRW-ASTR
# Successfully fetched data for KRW-PYTH
# Successfully fetched data for KRW-AKT
# Rate limit exceeded for KRW-STG. Retrying after 1 second.
# Successfully fetched data for KRW-ZETA
# Rate limit exceeded for KRW-BEAM. Retrying after 1 second.
# Rate limit exceeded for KRW-JUP. Retrying after 1 second.
# Successfully fetched data for KRW-USDT
# Rate limit exceeded for KRW-ENS. Retrying after 1 second.
# Successfully fetched data for KRW-AUCTION
# Successfully fetched data for KRW-ZRO
# Rate limit exceeded for KRW-UXLINK. Retrying after 1 second.
# Rate limit exceeded for KRW-G. Retrying after 1 second.
# Rate limit exceeded for KRW-USDC. Retrying after 1 second.
# Successfully fetched data for KRW-PENDLE
# Rate limit exceeded for KRW-ONDO. Retrying after 1 second.
# Rate limit exceeded for KRW-CKB. Retrying after 1 second.
# Rate limit exceeded for KRW-W. Retrying after 1 second.
# Rate limit exceeded for KRW-INJ. Retrying after 1 second.
# Successfully fetched data for KRW-BIGTIME
# Rate limit exceeded for KRW-SAFE. Retrying after 1 second.
# Rate limit exceeded for KRW-MEW. Retrying after 1 second.
# Rate limit exceeded for KRW-AGLD. Retrying after 1 second.
# Rate limit exceeded for KRW-DRIFT. Retrying after 1 second.
# Rate limit exceeded for KRW-UNI. Retrying after 1 second.
# Rate limit exceeded for KRW-PEPE. Retrying after 1 second.
# Rate limit exceeded for KRW-BONK. Retrying after 1 second.
# Successfully fetched data for KRW-JUP
# Successfully fetched data for KRW-ENS
# Successfully fetched data for KRW-G
# Successfully fetched data for KRW-UXLINK
# Rate limit exceeded for KRW-MEW. Retrying after 1 second.
# Rate limit exceeded for KRW-CKB. Retrying after 1 second.
# Rate limit exceeded for KRW-W. Retrying after 1 second.
# Successfully fetched data for KRW-INJ
# Successfully fetched data for KRW-ONDO
# Successfully fetched data for KRW-STG
# Successfully fetched data for KRW-USDC
# Successfully fetched data for KRW-BEAM
# Successfully fetched data for KRW-AGLD
# Rate limit exceeded for KRW-SAFE. Retrying after 1 second.
# Rate limit exceeded for KRW-UNI. Retrying after 1 second.
# Rate limit exceeded for KRW-DRIFT. Retrying after 1 second.
# Rate limit exceeded for KRW-BONK. Retrying after 1 second.
# Rate limit exceeded for KRW-PEPE. Retrying after 1 second.
# Successfully fetched data for KRW-W
# Successfully fetched data for KRW-MEW
# Successfully fetched data for KRW-CKB
# Successfully fetched data for KRW-UNI
# Successfully fetched data for KRW-BONK
# Successfully fetched data for KRW-SAFE
# Successfully fetched data for KRW-PEPE
# Successfully fetched data for KRW-DRIFT
# Сохранены свечи:       market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0   NEO-USDT  2024-11-29 10:07:00  2024-11-29T19:07:00      14.741007
# 1   ONT-USDT  2024-11-29 10:07:00  2024-11-29T19:07:00       0.266475
# 2  ARDR-USDT  2024-11-29 10:07:00  2024-11-29T19:07:00       0.115683
# 3   XLM-USDT  2024-11-29 10:07:00  2024-11-29T19:07:00       0.520863
# 4   SNT-USDT  2024-11-29 10:07:00  2024-11-29T19:07:00       0.044309
#
#    high_price  low_price  trade_price      timestamp  candle_acc_trade_price  \
# 0   14.741007  14.733813    14.741007  1732874876880            1.592328e+03
# 1    0.266475   0.266475     0.266475  1732874839299            5.043255e+02
# 2    0.116043   0.115683     0.116043  1732874851504            9.903954e+02
# 3    0.523957   0.520288     0.523022  1732874879465            1.137305e+06
# 4    0.044353   0.044309     0.044309  1732874876510            5.908407e+03
#
#    candle_acc_trade_volume  unit
# 0                 0.077714     1
# 1                 1.361570     1
# 2                 6.156526     1
# 3              1567.029961     1
# 4                95.848117     1
# Fetched 0 pairs
# Готово. См. файл: all_candles_merged.csv

# %%
import requests
import aiohttp
import asyncio
import pandas as pd
from datetime import datetime, timedelta

class UpbitDataFetcher:
    def __init__(self, batch_size=30, delay=2):
        self.base_url = "https://api.upbit.com/v1/candles/minutes/1"
        self.headers = {"accept": "application/json"}
        self.shit_list = ['KRW-USDT']
        self.filtered_pairs = []
        self.all_candles_data = []
        self.batch_size = batch_size
        self.delay = delay
        self.krw_usdt_rate = None  # Курс KRW/USDT

    def fetch_market_pairs(self):
        """Получает список всех пар с Upbit и фильтрует их."""
        url = "https://api.upbit.com/v1/market/all?isDetails=true"
        try:
            response = requests.get(url, headers=self.headers)
            response.raise_for_status()
            markets_data = response.json()

            df = pd.DataFrame(markets_data)
            self.filtered_pairs = df[
                df['market'].str.startswith('KRW-') & 
                ~df['market'].isin(self.shit_list)
            ]['market'].tolist()

            print(f"Filtered market pairs: {self.filtered_pairs[:5]} ...")
        except requests.exceptions.RequestException as e:
            print(f"An error occurred: {e}")

    async def fetch_krw_usdt_rate(self, session):
        """Получает курс KRW/USDT."""
        url = "https://api.upbit.com/v1/ticker"
        params = {"markets": "KRW-USDT"}
        try:
            async with session.get(url, params=params) as response:
                if response.status == 200:
                    data = await response.json()
                    if data:
                        self.krw_usdt_rate = data[0]["trade_price"]
                        print(f"KRW/USDT rate: {self.krw_usdt_rate}")
        except aiohttp.ClientError as e:
            print(f"Failed to fetch KRW-USDT rate: {e}")

    async def fetch_candle_data(self, pair, session):
        """Асинхронный метод для получения свечей по одной паре."""
        to_date = (datetime.utcnow() - timedelta(minutes=5)).strftime('%Y-%m-%dT%H:%M:%S')
        params = {'market': pair, 'count': 1, 'to': to_date}
        try:
            async with session.get(self.base_url, params=params, headers=self.headers) as response:
                response.raise_for_status()
                candles = await response.json()

                if candles:
                    # Конвертация цен в доллары
                    for candle in candles:
                        for key in ['opening_price', 'high_price', 'low_price', 'trade_price']:
                            candle[key] /= self.krw_usdt_rate
                        # Преобразуем пару в формат "SYMBOL/USDT" (если это Upbit)
                        if 'KRW-' in pair:
                            candle['market'] = f"{pair.replace('KRW-', '')}/USDT"
                        else:
                            candle['market'] = pair  # Для других бирж пары уже в нужном формате
                        candle['source'] = 'Upbit'
                    self.all_candles_data.extend(candles)
                    print(f"Fetched candles for {pair}")
                else:
                    print(f"No data for {pair}")
        except aiohttp.ClientError as e:
            print(f"Failed to fetch candles for {pair}: {e}")

    async def fetch_candles_batch(self, pairs_batch, session):
        tasks = [self.fetch_candle_data(pair, session) for pair in pairs_batch]
        await asyncio.gather(*tasks)

    async def fetch_all_candles(self):
        async with aiohttp.ClientSession() as session:
            await self.fetch_krw_usdt_rate(session)
            for i in range(0, len(self.filtered_pairs), self.batch_size):
                batch = self.filtered_pairs[i:i + self.batch_size]
                print(f"Fetching batch {i // self.batch_size + 1}")
                await self.fetch_candles_batch(batch, session)
                await asyncio.sleep(self.delay)

    def save_to_csv(self):
        """Сохраняет свечи в CSV с подписью источника."""
        if self.all_candles_data:
            df = pd.DataFrame(self.all_candles_data)
            df.to_csv("upbit_candles_usdt.csv", index=False)
            print("Saved to upbit_candles_usdt.csv")

    def run(self):
        """Запуск сбора данных."""
        self.fetch_market_pairs()
        asyncio.run(self.fetch_all_candles())
        self.save_to_csv()

# %%
class BinanceDataFetcher:
    def __init__(self):
        self.base_url_spot = "https://api.binance.com/api/v3/klines"
        self.base_url_perp = "https://fapi.binance.com/fapi/v1/klines"
        self.all_candles_data = {}

    async def fetch_candle(self, session, base_url, pair, interval="5m"):
        """Получает пятиминутную свечу для указанной пары с Binance."""
        # Преобразуем пары, как это нужно для Binance (например, 'NEO/USDT' -> 'NEOUSDT')
        pair_for_binance = pair.replace("/", "").replace("-", "")
        
        params = {
            "symbol": pair_for_binance,  # Формат пары, без "/"
            "interval": interval,
            "limit": 1,
            "endTime": int((datetime.utcnow() - timedelta(minutes=5)).timestamp() * 1000)
        }
        try:
            async with session.get(base_url, params=params) as response:
                if response.status == 200:
                    data = await response.json()
                    if data:
                        return {
                            "market": pair,
                            "source": "Binance",
                            "candle_date_time_utc": datetime.utcfromtimestamp(data[0][0] / 1000).strftime("%Y-%m-%d %H:%M:%S"),
                            "opening_price": float(data[0][1]),
                            "high_price": float(data[0][2]),
                            "low_price": float(data[0][3]),
                            "trade_price": float(data[0][4]),
                            "candle_acc_trade_price": float(data[0][7]),
                            "candle_acc_trade_volume": float(data[0][5])
                        }
        except aiohttp.ClientError as e:
            print(f"Error fetching candle for {pair} from {base_url}: {e}")
        return None

    async def fetch_candles_batch(self, pairs_batch, session):
        """Получает свечи для группы пар с Binance."""
        tasks = []
        for pair in pairs_batch:
            tasks.append(self.fetch_candle(session, self.base_url_spot, pair))
            tasks.append(self.fetch_candle(session, self.base_url_perp, pair))
        results = await asyncio.gather(*tasks)
        return results

    async def fetch_binance_data(self, upbit_pairs):
        """Основной метод для получения данных с Binance."""
        async with aiohttp.ClientSession() as session:
            batch_size = 10  # Число пар в одном пакете
            for i in range(0, len(upbit_pairs), batch_size):
                pairs_batch = upbit_pairs[i:i + batch_size]
                print(f"Fetching batch {i // batch_size + 1}")
                candles = await self.fetch_candles_batch(pairs_batch, session)
                for pair in pairs_batch:
                    pair_data = [c for c in candles if c and c['market'] == pair]
                    if not pair_data:
                        # Если нет данных с Binance, добавляем пустые строки для этой пары
                        self.all_candles_data[pair] = {
                            "market": pair,
                            "source": "Binance",
                            "candle_date_time_utc": datetime.utcnow().strftime("%Y-%m-%d %H:%M:%S"),
                            "opening_price": 0.0,
                            "high_price": 0.0,
                            "low_price": 0.0,
                            "trade_price": 0.0,
                            "candle_acc_trade_price": 0.0,
                            "candle_acc_trade_volume": 0.0
                        }
                    else:
                        # Если данные есть, сохраняем
                        for data in pair_data:
                            self.all_candles_data[pair] = data

    def combine_data(self, upbit_df):
        """Объединяет свечи Upbit и Binance в одну таблицу."""
        binance_df = pd.DataFrame(self.all_candles_data.values())  # Конвертируем в DataFrame

        # Переименовываем столбцы для данных Upbit
        upbit_df = upbit_df.rename(columns={
            "opening_price": "opening_price_upbit",
            "high_price": "high_price_upbit",
            "low_price": "low_price_upbit",
            "trade_price": "trade_price_upbit",
            "candle_acc_trade_price": "candle_acc_trade_price_upbit",
            "candle_acc_trade_volume": "candle_acc_trade_volume_upbit",
            "unit": "unit_upbit",
            "source": "source_upbit"
        })

        # Переименовываем столбцы для данных Binance
        binance_df = binance_df.rename(columns={
            "opening_price": "opening_price_binance",
            "high_price": "high_price_binance",
            "low_price": "low_price_binance",
            "trade_price": "trade_price_binance",
            "candle_acc_trade_price": "candle_acc_trade_price_binance",
            "candle_acc_trade_volume": "candle_acc_trade_volume_binance",
            "source": "source_binance"
        })

        # Объединяем данные по паре
        combined_df = pd.merge(
            upbit_df, binance_df, on="market", how="left"
        )

        self.combined_data = combined_df

    def save_combined_data(self):
        """Сохраняет объединенные данные в CSV."""
        if not self.combined_data.empty:
            self.combined_data.to_csv("combined_candles.csv", index=False)
            print("Сохранены объединенные данные:", self.combined_data.head())
        else:
            print("Нет данных для сохранения")

    def run(self, upbit_df):
        """Запуск сбора и обработки данных."""
        upbit_pairs = upbit_df["market"].unique().tolist()  # Извлекаем уникальные пары из DataFrame
        asyncio.run(self.fetch_binance_data(upbit_pairs))
        self.combine_data(upbit_df)
        self.save_combined_data()

# %%
# Создаем экземпляр класса для Upbit
upbit_fetcher = UpbitDataFetcher(batch_size=30, delay=2)

# Запуск сбора данных
upbit_fetcher.run()

# Считываем полученные свечи с Upbit
upbit_df = pd.read_csv("upbit_minute_candles_converted.csv")
print("Upbit Data:")
print(upbit_df.head())
# Out:
# Filtered market pairs: ['KRW-BTC', 'KRW-ETH', 'KRW-NEO', 'KRW-MTL', 'KRW-XRP'] ...
# KRW/USDT rate: 1390.0
# Fetching batch 1
# Fetched candles for KRW-BTC
# Fetched candles for KRW-XRP
# Fetched candles for KRW-ETH
# Fetched candles for KRW-XLM
# Fetched candles for KRW-LSK
# Fetched candles for KRW-MTL
# Fetched candles for KRW-STEEM
# Fetched candles for KRW-ADA
# Fetched candles for KRW-ONT
# Fetched candles for KRW-LOOM
# Failed to fetch candles for KRW-POWR: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-POWR&count=1&to=2024-11-29T11:46:42'
# Fetched candles for KRW-SBD
# Failed to fetch candles for KRW-ETC: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-ETC&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-QTUM: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-QTUM&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-SC: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-SC&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-TRX: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-TRX&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-NEO: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-NEO&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-WAVES: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-WAVES&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-ZRX: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-ZRX&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-ARK: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-ARK&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-ARDR: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-ARDR&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-STORJ: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-STORJ&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-POLYX: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-POLYX&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-ZIL: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-ZIL&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-XEM: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-XEM&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-BTG: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-BTG&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-ICX: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-ICX&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-SNT: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-SNT&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-EOS: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-EOS&count=1&to=2024-11-29T11:46:42'
# Failed to fetch candles for KRW-GRS: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-GRS&count=1&to=2024-11-29T11:46:42'
# Fetching batch 2
# Fetched candles for KRW-CVC
# Fetched candles for KRW-BAT
# Fetched candles for KRW-IOST
# Fetched candles for KRW-IQ
# Failed to fetch candles for KRW-GAS: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-GAS&count=1&to=2024-11-29T11:46:46'
# Fetched candles for KRW-IOTA
# Fetched candles for KRW-BOUNTY
# Fetched candles for KRW-HIFI
# Failed to fetch candles for KRW-QKC: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-QKC&count=1&to=2024-11-29T11:46:46'
# Fetched candles for KRW-ONG
# Failed to fetch candles for KRW-THETA: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-THETA&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-BSV: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-BSV&count=1&to=2024-11-29T11:46:46'
# Fetched candles for KRW-ELF
# Fetched candles for KRW-KNC
# Failed to fetch candles for KRW-BTT: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-BTT&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-TFUEL: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-TFUEL&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-ATOM: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-ATOM&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-ANKR: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-ANKR&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-AERGO: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-AERGO&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-BCH: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-BCH&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-MANA: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-MANA&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-MOC: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-MOC&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-TT: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-TT&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-GAME2: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-GAME2&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-MBL: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-MBL&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-HBAR: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-HBAR&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-WAXP: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-WAXP&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-MED: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-MED&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-MLK: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-MLK&count=1&to=2024-11-29T11:46:46'
# Failed to fetch candles for KRW-STPT: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-STPT&count=1&to=2024-11-29T11:46:46'
# Fetching batch 3
# Fetched candles for KRW-ORBS
# Fetched candles for KRW-VET
# Fetched candles for KRW-CHZ
# Failed to fetch candles for KRW-DKA: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-DKA&count=1&to=2024-11-29T11:46:48'
# Fetched candles for KRW-STMX
# Fetched candles for KRW-HIVE
# Fetched candles for KRW-KAVA
# Fetched candles for KRW-AHT
# Failed to fetch candles for KRW-LINK: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-LINK&count=1&to=2024-11-29T11:46:48'
# Fetched candles for KRW-XTZ
# Failed to fetch candles for KRW-BORA: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-BORA&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-SXP: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-SXP&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-JST: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-JST&count=1&to=2024-11-29T11:46:48'
# Fetched candles for KRW-TON
# Failed to fetch candles for KRW-HUNT: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-HUNT&count=1&to=2024-11-29T11:46:48'
# Fetched candles for KRW-CRO
# Failed to fetch candles for KRW-DOT: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-DOT&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-MVL: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-MVL&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-GLM: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-GLM&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-STRAX: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-STRAX&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-CBK: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-CBK&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-META: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-META&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-FCT2: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-FCT2&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-SAND: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-SAND&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-DOGE: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-DOGE&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-HPO: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-HPO&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-AQT: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-AQT&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-STRIKE: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-STRIKE&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-PUNDIX: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-PUNDIX&count=1&to=2024-11-29T11:46:48'
# Failed to fetch candles for KRW-FLOW: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-FLOW&count=1&to=2024-11-29T11:46:48'
# Fetching batch 4
# Fetched candles for KRW-STX
# Fetched candles for KRW-XEC
# Fetched candles for KRW-AXS
# Fetched candles for KRW-POL
# Fetched candles for KRW-SOL
# Fetched candles for KRW-AAVE
# Fetched candles for KRW-1INCH
# Failed to fetch candles for KRW-NEAR: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-NEAR&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-T: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-T&count=1&to=2024-11-29T11:46:50'
# Fetched candles for KRW-ALGO
# Fetched candles for KRW-AVAX
# Failed to fetch candles for KRW-GMT: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-GMT&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-CELO: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-CELO&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-APT: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-APT&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-EGLD: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-EGLD&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-ARB: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-ARB&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-SHIB: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-SHIB&count=1&to=2024-11-29T11:46:50'
# Fetched candles for KRW-MASK
# Failed to fetch candles for KRW-SUI: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-SUI&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-GRT: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-GRT&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-IMX: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-IMX&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-BLUR: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-BLUR&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-CTC: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-CTC&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-SEI: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-SEI&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-MINA: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-MINA&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-PYTH: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-PYTH&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-MNT: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-MNT&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-ASTR: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-ASTR&count=1&to=2024-11-29T11:46:50'
# Failed to fetch candles for KRW-ID: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-ID&count=1&to=2024-11-29T11:46:50'
# Fetched candles for KRW-AKT
# Fetching batch 5
# Fetched candles for KRW-ZETA
# Fetched candles for KRW-AUCTION
# Fetched candles for KRW-TAIKO
# Fetched candles for KRW-STG
# Fetched candles for KRW-BEAM
# Fetched candles for KRW-ONDO
# Failed to fetch candles for KRW-BLAST: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-BLAST&count=1&to=2024-11-29T11:46:54'
# Fetched candles for KRW-ZRO
# Failed to fetch candles for KRW-JUP: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-JUP&count=1&to=2024-11-29T11:46:54'
# Fetched candles for KRW-ENS
# Failed to fetch candles for KRW-W: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-W&count=1&to=2024-11-29T11:46:54'
# Fetched candles for KRW-G
# Failed to fetch candles for KRW-ATH: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-ATH&count=1&to=2024-11-29T11:46:54'
# Failed to fetch candles for KRW-BIGTIME: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-BIGTIME&count=1&to=2024-11-29T11:46:54'
# Failed to fetch candles for KRW-CKB: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-CKB&count=1&to=2024-11-29T11:46:54'
# Failed to fetch candles for KRW-PENDLE: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-PENDLE&count=1&to=2024-11-29T11:46:54'
# Fetched candles for KRW-USDC
# Failed to fetch candles for KRW-UXLINK: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-UXLINK&count=1&to=2024-11-29T11:46:54'
# Failed to fetch candles for KRW-CARV: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-CARV&count=1&to=2024-11-29T11:46:54'
# Failed to fetch candles for KRW-MEW: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-MEW&count=1&to=2024-11-29T11:46:54'
# Failed to fetch candles for KRW-INJ: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-INJ&count=1&to=2024-11-29T11:46:54'
# Failed to fetch candles for KRW-SAFE: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-SAFE&count=1&to=2024-11-29T11:46:54'
# Failed to fetch candles for KRW-DRIFT: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-DRIFT&count=1&to=2024-11-29T11:46:54'
# Failed to fetch candles for KRW-UNI: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-UNI&count=1&to=2024-11-29T11:46:54'
# Failed to fetch candles for KRW-AGLD: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-AGLD&count=1&to=2024-11-29T11:46:54'
# Failed to fetch candles for KRW-PEPE: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-PEPE&count=1&to=2024-11-29T11:46:54'
# Failed to fetch candles for KRW-BONK: 429, message='Too Many Requests', url='https://api.upbit.com/v1/candles/minutes/1?market=KRW-BONK&count=1&to=2024-11-29T11:46:54'
# Saved to upbit_candles_usdt.csv
# Upbit Data:
#      market candle_date_time_utc candle_date_time_kst  opening_price  \
# 0  NEO-USDT  2024-11-29 10:43:00  2024-11-29T19:43:00      14.783862
# 1  XRP-USDT  2024-11-29 10:43:00  2024-11-29T19:43:00       1.672190
# 2  BTG-USDT  2024-11-29 10:43:00  2024-11-29T19:43:00      34.661383
# 3  ICX-USDT  2024-11-29 10:42:00  2024-11-29T19:42:00       0.213256
# 4  ZRX-USDT  2024-11-29 10:43:00  2024-11-29T19:43:00       0.555403
#
#    high_price  low_price  trade_price      timestamp  candle_acc_trade_price  \
# 0   14.783862  14.783862    14.783862  1732877030672            4.295317e+03
# 1    1.676513   1.670749     1.676513  1732877039886            2.354148e+06
# 2   34.661383  34.632565    34.639769  1732877036686            2.156038e+04
# 3    0.213977   0.213256     0.213977  1732876955668            2.431672e+02
# 4    0.555476   0.555331     0.555331  1732877033783            1.674129e+04
#
#    candle_acc_trade_volume  unit
# 0                 0.209323     1
# 1              1012.502526     1
# 2                 0.448387     1
# 3                 0.821293     1
# 4                21.719223     1

# %%
# Предположим, что у вас уже есть DataFrame `upbit_df`
binance_fetcher = BinanceDataFetcher()
binance_fetcher.run(upbit_df)
# Out:
# Fetching batch 1
# Fetching batch 2
# Fetching batch 3
# Fetching batch 4
# Fetching batch 5
# Fetching batch 6
# Fetching batch 7
# Fetching batch 8
# Fetching batch 9
# Fetching batch 10
# Fetching batch 11
# Fetching batch 12
# Сохранены объединенные данные:      market candle_date_time_utc_x candle_date_time_kst  opening_price_upbit  \
# 0  NEO-USDT    2024-11-29 10:43:00  2024-11-29T19:43:00            14.783862
# 1  XRP-USDT    2024-11-29 10:43:00  2024-11-29T19:43:00             1.672190
# 2  BTG-USDT    2024-11-29 10:43:00  2024-11-29T19:43:00            34.661383
# 3  ICX-USDT    2024-11-29 10:42:00  2024-11-29T19:42:00             0.213256
# 4  ZRX-USDT    2024-11-29 10:43:00  2024-11-29T19:43:00             0.555403
#
#    high_price_upbit  low_price_upbit  trade_price_upbit      timestamp  \
# 0         14.783862        14.783862          14.783862  1732877030672
# 1          1.676513         1.670749           1.676513  1732877039886
# 2         34.661383        34.632565          34.639769  1732877036686
# 3          0.213977         0.213256           0.213977  1732876955668
# 4          0.555476         0.555331           0.555331  1732877033783
#
#    candle_acc_trade_price_upbit  candle_acc_trade_volume_upbit  unit_upbit  \
# 0                  4.295317e+03                       0.209323           1
# 1                  2.354148e+06                    1012.502526           1
# 2                  2.156038e+04                       0.448387           1
# 3                  2.431672e+02                       0.821293           1
# 4                  1.674129e+04                      21.719223           1
#
#   source_binance candle_date_time_utc_y  opening_price_binance  \
# 0        Binance    2024-11-29 07:45:00                14.5110
# 1        Binance    2024-11-29 07:45:00                 1.6085
# 2        Binance    2022-10-24 08:55:00                17.8300
# 3        Binance    2024-11-29 07:45:00                 0.2093
# 4        Binance    2024-11-29 07:45:00                 0.5397
#
#    high_price_binance  low_price_binance  trade_price_binance  \
# 0             14.5390            14.5030              14.5320
# 1              1.6169             1.6048               1.6128
# 2             17.8300            17.6200              17.6500
# 3              0.2099             0.2091               0.2095
# 4              0.5408             0.5393               0.5403
#
#    candle_acc_trade_price_binance  candle_acc_trade_volume_binance
# 0                    2.551847e+04                          1757.62
# 1                    1.961565e+07                      12173498.50
# 2                    3.243560e+04                          1828.42
# 3                    6.348801e+04                        302888.00
# 4                    2.619904e+04                         48509.70

# %%
import pandas as pd

# Загрузка данных
input_path = "combined_candles.csv"  # Замените на путь к вашему файлу
combined_candles = pd.read_csv(input_path)

# Переименование колонок для удобства
combined_candles.rename(columns={
    'candle_date_time_utc_x': 'candle_date_time_utc',
    'trade_price_x': 'trade_price_upbit',
    'candle_acc_trade_price_x': 'candle_acc_trade_price_upbit',
    'candle_acc_trade_volume_x': 'candle_acc_trade_volume_upbit',
    'candle_date_time_utc_y': 'candle_date_time_utc_binance',
    'trade_price_y': 'trade_price_binance',
    'candle_acc_trade_price_y': 'candle_acc_trade_price_binance',
    'candle_acc_trade_volume_y': 'candle_acc_trade_volume_binance',
}, inplace=True)

# Выбор и упорядочивание необходимых столбцов
columns_order = [
    'market', 
    'candle_date_time_utc_upbit', 
    'candle_date_time_kst', 
    'trade_price_upbit', 
    'timestamp', 
    'candle_acc_trade_price_upbit', 
    'candle_acc_trade_volume_upbit', 
    'unit_upbit', 
    'source_binance', 
    'candle_date_time_utc_binance', 
    'opening_price_binance', 
    'high_price_binance', 
    'low_price_binance', 
    'trade_price_binance', 
    'candle_acc_trade_price_binance', 
    'candle_acc_trade_volume_binance'
]

formatted_table = combined_candles[columns_order]

# Сохранение результата в CSV
output_path = "formatted_combined_candles.csv"
formatted_table.to_csv(output_path, index=False)

print(f"Форматированная таблица успешно сохранена в {output_path}")
# Out:
# Форматированная таблица успешно сохранена в formatted_combined_candles.csv

# %%
import sqlite3

# Открытие соединения с базой данных
conn = sqlite3.connect('/Users/user/Desktop/upbit vs binance/crypto_prices.db')
cursor = conn.cursor()

# Выполнение запроса к таблице crypto_prices
cursor.execute("SELECT * FROM crypto_prices LIMIT 10;")
for row in cursor.fetchall():
    print(row)

# Закрытие соединения
conn.close()
